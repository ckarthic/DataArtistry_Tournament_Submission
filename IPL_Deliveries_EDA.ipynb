# %%
import urllib.request, json 
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./IPL_Deliveries_Full.csv")
df.shape
# Out:
# (136598, 21)

# %%
df.dtypes
# Out:
# match_id             int64
# inning               int64
# batting_team        object
# bowling_team        object
# over                 int64
# ball                 int64
# batsman             object
# non_striker         object
# bowler              object
# is_super_over        int64
# wide_runs            int64
# bye_runs             int64
# legbye_runs          int64
# noball_runs          int64
# penalty_runs         int64
# batsman_runs         int64
# extra_runs           int64
# total_runs           int64
# player_dismissed    object
# dismissal_kind      object
# fielder             object
# dtype: object

# %%
df.dismissal_kind.unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'retired hurt',
#        'stumped', 'caught and bowled', 'hit wicket',
#        'obstructing the field'], dtype=object)

# %%
#df.groupby('batsman')['match_id'].count().sort_values(ascending = False)[:100]
#batsmanByball = df.groupby('batsman').aggregate({'ball': 'count', 'batsman_runs' : 'sum'}).sort_values(
    #'ball', ascending = False)[:100]
batsmanByball['strikerate'] = batsmanByball['batsman_runs']/batsmanByball['ball'] * 100
batsmanByball.sort_values(['strikerate','ball'], ascending = False)
# Out:
#                  ball  batsman_runs  strikerate
# batsman
# AD Russell        350           574  164.000000
# GJ Maxwell        594           919  154.713805
# V Sehwag         1833          2728  148.827059
# AB de Villiers   2231          3270  146.571044
# CH Gayle         2360          3451  146.228814
# YK Pathan        1953          2779  142.293907
# KA Pollard       1380          1959  141.956522
# DA Miller        1053          1480  140.550807
# DA Warner        2440          3373  138.237705
# JA Morkel         712           975  136.938202
# SR Watson        1869          2557  136.811129
# JP Faulkner       346           473  136.705202
# Harbhajan Singh   574           783  136.411150
# MS Dhoni         2419          3270  135.179826
# SK Raina         3059          4106  134.226872
# ST Jayasuriya     573           768  134.031414
# AC Gilchrist     1555          2069  133.054662
# SPD Smith         933          1241  133.011790
# ...
